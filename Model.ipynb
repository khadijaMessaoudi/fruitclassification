# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d misrakahmed/vegetable-image-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/misrakahmed/vegetable-image-dataset
# License(s): CC-BY-SA-4.0
# vegetable-image-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

dataset_zip = "vegetable-image-dataset.zip"  # Change si besoin
with zipfile.ZipFile(dataset_zip, 'r') as zip_ref:
    zip_ref.extractall("dataset/")  # Dossier de destination

print("✅ Dataset téléchargé et extrait avec succès !")
# Out:
# ✅ Dataset téléchargé et extrait avec succès !

# %%
# !apt-get install -y libimage-exiftool-perl

# %%
# !pip install tensorflow
# !pip install opencv-python-headless

# %%
import os
import cv2
import numpy as np

def remove_blurry_images_from_all_folders(base_folder, threshold=100):
    blurry_images = []

    # Parcours tous les sous-dossiers (train, test, validation)
    for folder in os.listdir(base_folder):
        folder_path = os.path.join(base_folder, folder)

        if os.path.isdir(folder_path):  # Vérifier si c'est un dossier
            # Parcours tous les sous-dossiers de légumes (par exemple: 'Radish', 'Cucumber', etc.)
            for vegetable_folder in os.listdir(folder_path):
                vegetable_folder_path = os.path.join(folder_path, vegetable_folder)

                if os.path.isdir(vegetable_folder_path):  # Vérifier si c'est un sous-dossier de légumes
                    # Parcours toutes les images dans ce sous-dossier
                    for filename in os.listdir(vegetable_folder_path):
                        img_path = os.path.join(vegetable_folder_path, filename)

                        # Vérifie si c'est une image valide (extensions comme .jpg, .png, etc.)
                        if not filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                            continue

                        img = cv2.imread(img_path)

                        # Vérifie si l'image a été correctement chargée
                        if img is None:
                            print(f"Warning: Could not load image {img_path}")
                            continue

                        # Conversion en niveaux de gris et calcul de la variance de Laplacian
                        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                        variance = cv2.Laplacian(gray, cv2.CV_64F).var()

                        # Si la variance est inférieure au seuil, l'image est floue
                        if variance < threshold:
                            blurry_images.append(img_path)

    return blurry_images

# Exemple d'utilisation avec le dossier de base
blurry_images = remove_blurry_images_from_all_folders('/content/dataset/Vegetable Images')
print("Images floues:", blurry_images)
# Out:
# Images floues: ['/content/dataset/Vegetable Images/train/Bottle_Gourd/0285.jpg', '/content/dataset/Vegetable Images/train/Carrot/0032.jpg', '/content/dataset/Vegetable Images/train/Carrot/0073.jpg', '/content/dataset/Vegetable Images/train/Carrot/0295.jpg', '/content/dataset/Vegetable Images/train/Carrot/0598.jpg', '/content/dataset/Vegetable Images/train/Carrot/0604.jpg', '/content/dataset/Vegetable Images/train/Carrot/0188.jpg', '/content/dataset/Vegetable Images/train/Carrot/0106.jpg', '/content/dataset/Vegetable Images/train/Carrot/0293.jpg', '/content/dataset/Vegetable Images/train/Carrot/0069.jpg', '/content/dataset/Vegetable Images/train/Carrot/0963.jpg', '/content/dataset/Vegetable Images/train/Carrot/0851.jpg', '/content/dataset/Vegetable Images/train/Carrot/0002.jpg', '/content/dataset/Vegetable Images/train/Carrot/0389.jpg', '/content/dataset/Vegetable Images/train/Carrot/0700.jpg', '/content/dataset/Vegetable Images/train/Carrot/0404.jpg', '/content/dataset/Vegetable Images/train/Carrot/0421.jpg', '/content/dataset/Vegetable Images/train/Carrot/0988.jpg', '/content/dataset/Vegetable Images/train/Carrot/0078.jpg', '/content/dataset/Vegetable Images/train/Carrot/0447.jpg', '/content/dataset/Vegetable Images/train/Carrot/0077.jpg', '/content/dataset/Vegetable Images/train/Carrot/0571.jpg', '/content/dataset/Vegetable Images/train/Carrot/0161.jpg', '/content/dataset/Vegetable Images/train/Carrot/0800.jpg', '/content/dataset/Vegetable Images/train/Carrot/0686.jpg', '/content/dataset/Vegetable Images/train/Carrot/0067.jpg', '/content/dataset/Vegetable Images/train/Carrot/0275.jpg', '/content/dataset/Vegetable Images/train/Carrot/0169.jpg', '/content/dataset/Vegetable Images/train/Carrot/0401.jpg', '/content/dataset/Vegetable Images/train/Carrot/0777.jpg', '/content/dataset/Vegetable Images/train/Carrot/0507.jpg', '/content/dataset/Vegetable Images/train/Carrot/0202.jpg', '/content/dataset/Vegetable Images/train/Carrot/0122.jpg', '/content/dataset/Vegetable Images/train/Carrot/0772.jpg', '/content/dataset/Vegetable Images/train/Carrot/0932.jpg', '/content/dataset/Vegetable Images/train/Carrot/0521.jpg', '/content/dataset/Vegetable Images/train/Carrot/0979.jpg', '/content/dataset/Vegetable Images/train/Carrot/0338.jpg', '/content/dataset/Vegetable Images/train/Carrot/0954.jpg', '/content/dataset/Vegetable Images/train/Carrot/0379.jpg', '/content/dataset/Vegetable Images/train/Carrot/0199.jpg', '/content/dataset/Vegetable Images/train/Carrot/0441.jpg', '/content/dataset/Vegetable Images/train/Carrot/0172.jpg', '/content/dataset/Vegetable Images/train/Carrot/0855.jpg', '/content/dataset/Vegetable Images/train/Carrot/0654.jpg', '/content/dataset/Vegetable Images/train/Carrot/0595.jpg', '/content/dataset/Vegetable Images/train/Carrot/0667.jpg', '/content/dataset/Vegetable Images/train/Carrot/0890.jpg', '/content/dataset/Vegetable Images/train/Carrot/0789.jpg', '/content/dataset/Vegetable Images/train/Carrot/0503.jpg', '/content/dataset/Vegetable Images/train/Carrot/0038.jpg', '/content/dataset/Vegetable Images/train/Carrot/0556.jpg', '/content/dataset/Vegetable Images/train/Carrot/0728.jpg', '/content/dataset/Vegetable Images/train/Carrot/0207.jpg', '/content/dataset/Vegetable Images/train/Carrot/0913.jpg', '/content/dataset/Vegetable Images/train/Carrot/0318.jpg', '/content/dataset/Vegetable Images/train/Carrot/0548.jpg', '/content/dataset/Vegetable Images/train/Carrot/0865.jpg', '/content/dataset/Vegetable Images/train/Carrot/0891.jpg', '/content/dataset/Vegetable Images/train/Carrot/0035.jpg', '/content/dataset/Vegetable Images/train/Carrot/0005.jpg', '/content/dataset/Vegetable Images/train/Carrot/0946.jpg', '/content/dataset/Vegetable Images/train/Carrot/0334.jpg', '/content/dataset/Vegetable Images/train/Carrot/0745.jpg', '/content/dataset/Vegetable Images/train/Carrot/0967.jpg', '/content/dataset/Vegetable Images/train/Carrot/0100.jpg', '/content/dataset/Vegetable Images/train/Carrot/0050.jpg', '/content/dataset/Vegetab ...

# %%
from PIL import Image
import os

def check_resolution(image_path, min_width=200, min_height=200):
    """Vérifie si l'image a une résolution suffisante."""
    try:
        with Image.open(image_path) as img:
            width, height = img.size
            return width >= min_width and height >= min_height
    except Exception as e:
        print(f"Erreur lors de l'ouverture de l'image {image_path}: {e}")
        return False  # Considère l'image comme invalide en cas d'erreur

for img_path in blurry_images:  # Remplacement de 'image_paths' par 'blurry_images'
    if not check_resolution(img_path):
        os.remove(img_path)  # Supprime les images qui ne respectent pas les dimensions minimales
        print(f"Supprimé : {img_path}")

# %%
# !pip install opencv-python numpy
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)

# %%
#Correction de la Balance des Blancs

# %%
import cv2
import numpy as np
import os

def white_balance(img):
    """Correction de la balance des blancs avec l'espace couleur LAB"""
    result = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    avg_a = np.mean(result[:, :, 1])
    avg_b = np.mean(result[:, :, 2])
    result[:, :, 1] = result[:, :, 1] - ((avg_a - 128) * (result[:, :, 0] / 255.0) * 1.1)
    result[:, :, 2] = result[:, :, 2] - ((avg_b - 128) * (result[:, :, 0] / 255.0) * 1.1)
    return cv2.cvtColor(result, cv2.COLOR_LAB2BGR)

input_folder = "dataset"
output_folder = "enhanced_dataset"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

files_processed = 0  # Compteur d'images traitées

# Parcourir tous les sous-dossiers et fichiers dans le dossier 'dataset'
for root, dirs, files in os.walk(input_folder):
    for file_name in files:
        img_path = os.path.join(root, file_name)

        # Vérifier si c'est un fichier image
        if not file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            print(f" Fichier ignoré (pas une image) : {file_name}")
            continue

        img = cv2.imread(img_path)

        if img is None:
            print(f"⚠️ Impossible de charger : {img_path}")
        else:
            wb_img = white_balance(img)

            # Construire le chemin de sortie en conservant la structure du dossier
            relative_path = os.path.relpath(root, input_folder)
            output_subfolder = os.path.join(output_folder, relative_path)

            if not os.path.exists(output_subfolder):
                os.makedirs(output_subfolder)

            output_path = os.path.join(output_subfolder, file_name)

            cv2.imwrite(output_path, wb_img)
            print(f"✅ Image corrigée et enregistrée : {output_path}")
            files_processed += 1

if files_processed == 0:
    print("⚠️ Aucune image n'a été traitée. Vérifie le dossier 'dataset'.")

print(" Balance des blancs appliquée avec succès !")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1245.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1370.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1319.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1351.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1241.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1340.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1230.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1327.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1357.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1354.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1334.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1223.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1250.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1341.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1238.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1208.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1301.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1321.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1365.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1316.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1363.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1308.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1344.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1248.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1369.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1211.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1381.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1264.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1276.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1279.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1224.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1282.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1237.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1267.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1387.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1368.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1323.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1292.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1272.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1326.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1303.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1298.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1277.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1221.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1227.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1302.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1202.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1349.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1359.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1392.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1232.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1309.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1225.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1229.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1314.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1388.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1226.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1311.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1283.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1215.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1375.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1234.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1297.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1220.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1384.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1382.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1217.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1360.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1315.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1397.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1312.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1337.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1275.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1398.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1324.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1233.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1222.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1304.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1265.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1335.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1317.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1207.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1261.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1389.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1396.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1209.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1262.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1203.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1333.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1307.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1328.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1306.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1287.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1305.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1399.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1246.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1329.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1366.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1395.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1231.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1347.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1310.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1294.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1322.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1339.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1269.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1358.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1280.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1251.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1356.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1300.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1249.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1362.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1350.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1201.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1393.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1257.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1216.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1371.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1242.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1290.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1286.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1291.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1348.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1331.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1266.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1343.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1268.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1394.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1228.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1247.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1346.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1274.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1400.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1214.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1336.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1243.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1330.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1390.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1332.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1259.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1260.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1352.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1218.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1313.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1320.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1263.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1293.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1361.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1284.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1206.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1373.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1338.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1273.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1256.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1281.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1380.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1219.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1240.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1367.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1355.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1364.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1378.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1386.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1391.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1295.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1252.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1353.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1244.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1379.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1342.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1285.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1385.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1383.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1236.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1345.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1372.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1235.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1270.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1374.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1288.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1318.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1254.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1258.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1296.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1325.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1377.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1253.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1204.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1205.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1278.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1376.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1299.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1289.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1210.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1255.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1239.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1213.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Bitter_Gourd/1271.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1136.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1162.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1066.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1109.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1148.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1028.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1038.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1032.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1117.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1010.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1198.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1078.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1118.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1076.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1115.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1179.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1018.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1121.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1169.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1123.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1145.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1163.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1009.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1043.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1088.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1144.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1127.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1200.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1035.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1193.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1047.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1112.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1168.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1045.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1011.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1160.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1186.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1073.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1054.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1072.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1005.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1167.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1181.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1177.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1129.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1188.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1051.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1092.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1150.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1153.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1120.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1033.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1171.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1116.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1012.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1090.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1062.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1131.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1140.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1049.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1098.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1031.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1133.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1143.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1017.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1097.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1069.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1055.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1079.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1164.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1006.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1135.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1022.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1194.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1016.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1044.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1053.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1020.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1399.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1108.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1137.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1199.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1093.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1142.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1149.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1036.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1192.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1172.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1173.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1113.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1024.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1021.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1122.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1184.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1025.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1104.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1048.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1178.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1180.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1015.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1159.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1138.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1042.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1107.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1141.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1039.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1059.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1003.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1165.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1156.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1050.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1071.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1095.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1077.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1157.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1091.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1014.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1096.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1390.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1004.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1002.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1124.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1166.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1103.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1197.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1106.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1176.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1007.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1064.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1084.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1068.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1128.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1158.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1125.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1183.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1067.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1187.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1170.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1082.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1046.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1147.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1029.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1132.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1056.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1063.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1195.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1094.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1152.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1130.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1057.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1023.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1100.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1070.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1052.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1085.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1191.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1126.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1040.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1182.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1196.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1139.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1111.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1134.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1089.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1161.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1175.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1185.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1060.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1087.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1061.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1114.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1102.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1189.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1001.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1058.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1119.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1174.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1030.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1027.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1065.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1105.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1019.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1008.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1099.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1075.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1037.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1086.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1190.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1080.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1154.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1074.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1081.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1151.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1155.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1110.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1146.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1013.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1101.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1041.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Potato/1083.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1136.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1162.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1066.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1245.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1241.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1230.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1109.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1223.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1148.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1250.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1238.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1208.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1117.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1198.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1248.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1078.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1211.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1118.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1076.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1115.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1179.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1224.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1237.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1121.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1169.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1123.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1145.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1163.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1088.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1221.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1227.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1144.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1202.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1127.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1200.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1232.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1193.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1112.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1225.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1168.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1229.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1226.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1160.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1186.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1073.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1054.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1072.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1167.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1181.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1177.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1215.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1129.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1188.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1051.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1092.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1150.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1234.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1153.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1120.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1220.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1116.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1217.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1090.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1062.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1131.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1140.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1049.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1233.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1098.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1133.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1143.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1097.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1207.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1069.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1055.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1079.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1164.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1135.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1209.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1203.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1194.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1053.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1246.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1108.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1137.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1231.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1199.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1093.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1142.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1149.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1251.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1172.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1173.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1113.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1249.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1201.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1216.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1242.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1122.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1184.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1104.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1048.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1178.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1180.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1228.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1247.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1159.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1138.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1107.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1141.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1214.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1059.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1243.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1165.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1156.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1050.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1071.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1095.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/test/Cauliflower/1077.jpg
# ...
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1267.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1387.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1368.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1323.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1292.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1272.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1326.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1303.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1298.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1277.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1221.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1227.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1302.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1202.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1349.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1200.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1359.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1392.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1232.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1309.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1225.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1229.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1314.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1388.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1226.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1311.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1283.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1215.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1375.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1234.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1297.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1220.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1384.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1382.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1217.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1360.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1315.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1397.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1312.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1337.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1275.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1398.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1324.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1222.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1304.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1265.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1335.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1317.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1207.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1261.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1389.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1396.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1209.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1262.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1203.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1333.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1307.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1328.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1401.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1306.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1287.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1305.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1399.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1246.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1329.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1366.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1395.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1231.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1347.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1199.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1310.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1294.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1322.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1339.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1269.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1358.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1280.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1251.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1356.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1300.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1249.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1362.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1350.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1201.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1393.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1257.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1216.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1371.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1242.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1290.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1286.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1291.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1331.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1266.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1343.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1268.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1394.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1228.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1247.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1346.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1274.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1214.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1336.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1243.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1330.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1390.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1332.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1259.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1260.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1352.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1197.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1218.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1313.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1320.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1263.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1293.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1361.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1284.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1206.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1373.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1338.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1256.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1281.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1380.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1219.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1240.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1367.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1355.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1364.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1386.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1391.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1295.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1252.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1353.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1244.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1379.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1342.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1285.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1385.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1383.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1236.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1345.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1372.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1235.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1270.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1374.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1288.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1318.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1254.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1258.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1296.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1325.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1377.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1253.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1204.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1205.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1278.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1376.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1299.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1289.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1210.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1255.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1239.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1213.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1402.jpg
# ✅ Image corrigée et enregistrée : enhanced_dataset/Vegetable Images/validation/Cabbage/1271.jpg
#  Balance des blancs appliquée avec succès !

# %%
#data augumentation :

# %%
#augumentation sur toutes la data_set:
import cv2
import numpy as np
import os

# Fonction pour effectuer une rotation de l'image
def rotate_image(img, angle):
    (h, w) = img.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(img, matrix, (w, h))
    return rotated

# Fonction pour ajuster la luminosité de l'image
def adjust_brightness(img, factor):
    return cv2.convertScaleAbs(img, alpha=factor, beta=0)

# Augmentation d'image et sauvegarde dans le dossier de sortie
input_folder = "enhanced_dataset"
output_folder = "augmented_dataset"

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

files_processed = 0  # Compteur d'images traitées

for root, dirs, files in os.walk(input_folder):
    for file_name in files:
        img_path = os.path.join(root, file_name)

        if not file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            continue

        img = cv2.imread(img_path)

        if img is None:
            print(f"⚠️ Impossible de charger : {img_path}")
        else:
            # Augmentations
            rotated_img = rotate_image(img, 15)  # Rotation de 15 degrés
            bright_img = adjust_brightness(img, 1.2)  # Augmentation de la luminosité (facteur 1.2)

            # Sauvegarde des images augmentées
            relative_path = os.path.relpath(root, input_folder)
            output_subfolder = os.path.join(output_folder, relative_path)

            if not os.path.exists(output_subfolder):
                os.makedirs(output_subfolder)

            # Enregistrer les images augmentées
            cv2.imwrite(os.path.join(output_subfolder, f"rotated_{file_name}"), rotated_img)
            cv2.imwrite(os.path.join(output_subfolder, f"bright_{file_name}"), bright_img)
            files_processed += 2  # 2 images générées par image traitée

if files_processed == 0:
    print("Aucune image n'a été augmentée.")
else:
    print("Augmentation d'images terminée !")
# Out:
# Augmentation d'images terminée !

# %%
import os

input_folder = "enhanced_dataset"
output_folder = "/content/augmented_dataset/Vegetable Images"

# Compter le nombre d'images avant augmentation
num_images_before = sum(len(files) for _, _, files in os.walk(input_folder))
print(f"Nombre d'images avant augmentation: {num_images_before}")

# Compter le nombre d'images après augmentation
num_images_after = sum(len(files) for _, _, files in os.walk(output_folder))
print(f"Nombre d'images après augmentation: {num_images_after}")

# Vérification
if num_images_after > num_images_before:
    print("Les images ont été augmentées avec succès !")
else:
    print("⚠️ Aucune augmentation détectée, vérifie le script !")
# Out:
# Nombre d'images avant augmentation: 21000
# Nombre d'images après augmentation: 42000
# Les images ont été augmentées avec succès !

# %%
# !pip install tensorflow numpy matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
#vérification de repartition de dataset

# %%
import os

dataset_path = "/content/augmented_dataset/Vegetable Images"  # Remplace par le chemin de ton dataset
subsets = ["test", "train", "validation"]

for subset in subsets:
    subset_path = os.path.join(dataset_path, subset)
    if os.path.exists(subset_path):
        total_images = sum([len(files) for _, _, files in os.walk(subset_path)])
        print(f"Nombre d'images dans {subset}: {total_images}")
    else:
        print(f"Le dossier {subset} n'existe pas !")
# Out:
# Nombre d'images dans test: 6000
# Nombre d'images dans train: 30000
# Nombre d'images dans validation: 6000

# %%
train_count = sum([len(files) for _, _, files in os.walk(os.path.join(dataset_path, "train"))])
val_count = sum([len(files) for _, _, files in os.walk(os.path.join(dataset_path, "validation"))])
test_count = sum([len(files) for _, _, files in os.walk(os.path.join(dataset_path, "test"))])

total = train_count + val_count + test_count

train_percentage = (train_count / total) * 100
val_percentage = (val_count / total) * 100
test_percentage = (test_count / total) * 100

print(f"Train: {train_percentage:.2f}% ({train_count} images)")
print(f"Validation: {val_percentage:.2f}% ({val_count} images)")
print(f"Test: {test_percentage:.2f}% ({test_count} images)")

# %%
#CHARGER data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Définition des répertoires
train_dir = "/content/augmented_dataset/Vegetable Images/train"
val_dir = "/content/augmented_dataset/Vegetable Images/validation"
test_dir = "/content/augmented_dataset/Vegetable Images/test"

img_size = (224, 224)
batch_size = 32

# Générateur de données avec normalisation
datagen = ImageDataGenerator(rescale=1./255)

# Chargement des images
train_data = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_data = datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_data = datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

print("Données chargées avec succès !")

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Charger ResNet50 sans la dernière couche
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Débloquer les 20 dernières couches pour le fine-tuning
for layer in base_model.layers[:-20]:
    layer.trainable = False
for layer in base_model.layers[-20:]:
    layer.trainable = True

# Ajouter des couches personnalisées
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.2)(x)  # Nouveau Dropout après le pooling global
x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)  # Déjà présent, bon choix
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)  # Augmenté à 0.4 pour plus de régularisation
x = Dense(15, activation='softmax')(x)  # 15 classes de légumes

# Créer et compiler le modèle
model = Model(inputs=base_model.input, outputs=x)
model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# Afficher le résumé du modèle
model.summary()

# %%
epochs = 8 # Nombre d'époques (peut être augmenté si besoin)

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs
)

# %%
import matplotlib.pyplot as plt

# Courbes de précision
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Courbe d’Accuracy')
plt.show()

# Courbes de perte
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Courbe de Loss')
plt.show()

# %%
model.save('final_vegetable_model.keras')

# %%
model.save('final_model.h5')

# %%
from google.colab import files
files.download('/content/final_vegetable_model.h5')
